# %%
import requests

def translyric_savefile(trans_list, title):
    with open(f'data/{title}_trans.txt','w',encoding='utf8') as file:
        file.writelines(trans_list)

#yesterday.txt 가사 파일의 내용을 읽어서 list에 저장
def gettext_savelist(title):
    lyric_list = []
    with open(f'data/{title}.txt','r',encoding='utf8') as file:
        contents = file.read()
        lyric_list = contents.split('\n')
    return lyric_list
    
def main(title, source, target):
    client_id = "ZzyBY635Yl2U3JjFzNt2"
    client_secret = "AEKs6skA8R"
    
    url = "https://openapi.naver.com/v1/papago/n2mt"

    #request header 값 선언
    req_header = {
        "X-Naver-Client-Id":client_id,
        "X-Naver-Client-Secret":client_secret
    }
    #yesterday.txt 가사 파일의 내용을 읽어서 list에 저장
    lyric_list = gettext_savelist(title)
    print(len(lyric_list))
    # list comprehension
    lyric_list = [lyric for lyric in lyric_list if len(lyric) != 0]    # empty string을 제외하고 리스트에 저장
    print(len(lyric_list))
    
    trans_list = []
    print('>> 번역시작')
    for req_lyric in lyric_list:
        print(req_lyric)
        #request form data 값 선언
        req_data = {
            "source":source,
            "target":target,
            "text":req_lyric
        }
        #papago 서비스 요청, post() 함수 호출
        res = requests.post(url, data=req_data, headers=req_header)
        
        try:
            trans_lyric = res.json()['message']['result']['translatedText']
        except Exception as exp:
            print(exp)
            print(res.status_code)
        else:
            print(trans_lyric)
        
        trans_list.append(req_lyric+'\n')
        trans_list.append(trans_lyric+'\n')
    # print(trans_list)
    translyric_savefile(trans_list, title)
    print('>> 번역 종료')
    
main('yesterday', 'en', 'ja')
# Out:
# 23
# 17
# >> 번역시작
# Yesterday all my troubles seemed so far away.
# 昨日は私の悩みはすべて遠くに見えた。
# Now it looks as though they're here to stay.
# 彼らはここに滞在しているようです。
# Oh, I believe in yesterday.
# ああ  昨日のことを信じます
# Suddenly I'm not half the man I used to be.
# 突然私は以前のような人間になった
# There's a shadow hanging over me.
# 影が差している
# Oh, yesterday came suddenly.
# あっ、昨日が突然やってきた。
# Why she had to go, I don't know, she wouldn't say.
# なぜ彼女が行かねばならなかったのか,  私にはわからない,  彼女はどうしても言わなかった
# I said something wrong, now I long for yesterday.
# 私は何か間違ったことを言った,  今は昨日が恋しい
# Yesterday love was such an easy game to play.
# 昨日の恋はとても簡単なゲームだった。
# Now I need a place to hide away.
# 私は今、隠れる場所が必要です。
# Oh, I believe in yesterday.
# ああ  昨日のことを信じます
# Why she had to go, I don't know, she wouldn't say.
# なぜ彼女が行かねばならなかったのか,  私にはわからない,  彼女はどうしても言わなかった
# I said something wrong, now I long for yesterday.
# 私は何か間違ったことを言った,  今は昨日が恋しい
# Yesterday love was such an easy game to play.
# 昨日の恋はとても簡単なゲームだった。
# Now I need a place to hide away.
# 私は今、隠れる場所が必要です。
# Oh, I believe in yesterday.
# ああ  昨日のことを信じます
# Mm mm mm mm mm mm mm
# mm  mm  mm  mm  mm  mm
# >> 번역 종료
